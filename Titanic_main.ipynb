# %% [markdown]
# # 模組化課程 - 作業
#
# 本作業使用 [Kaggle Titanic](https://www.kaggle.com/c/titanic/overview) 所提供的資料，根據鐵達尼號乘客資料預測生還者。
# 我們只使用 `train.csv` 進行生還者預測（只有 `train.csv` 才有答案），而加分題需要額外使用 `test.csv` 並提交至 [Kaggle Titanic](https://www.kaggle.com/c/titanic/overview) 進行評分。
#
# 本作業需要先學習[程式教材](https://github.com/IKMLab/course_material)中的以下部份：
#
# - [jupyter-基本功能](https://github.com/IKMLab/course_material/blob/master/jupyter-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)
# - [python-入門語法](https://github.com/IKMLab/course_material/blob/master/python-%E5%85%A5%E9%96%80%E8%AA%9E%E6%B3%95.ipynb)
# - [numpy-基本功能](https://github.com/IKMLab/course_material/blob/master/numpy-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)
# - [pandas-基本功能](https://github.com/IKMLab/course_material/blob/master/pandas-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)
# - [matplotlib-資料視覺化](https://github.com/IKMLab/course_material/blob/master/matplotlib-%E8%B3%87%E6%96%99%E8%A6%96%E8%A6%BA%E5%8C%96.ipynb)
# - [scikit-learn-基本功能](https://github.com/IKMLab/course_material/blob/master/scikit-learn-%E5%9F%BA%E6%9C%AC%E5%8A%9F%E8%83%BD.ipynb)

# %% [markdown]
# ## 繳交規則
#
# 1. 請將**當前資料夾**命名為 `HW1_你的學號`
#     - 例如：`HW1_F12345678`
#     - 所有**英文**都必須**大寫**
# 2. 請將本檔案命名為 `main.ipynb`
# 3. 請描述開發所需要的**環境**，包含：
#     - **作業系統**與**發行版本**
#         - 例如：Windows、Mac、Linux 等
#         - 需要填寫系統**名稱**與**版本**
#         - 如果是使用雲端計算資源 (e.g. Colab) 則直接註明雲端計算平台名稱
#     - **程式執行環境**
#         - 例如：jupyter、Kaggle kernel、Colab 等
#         - 如果是 jupyter 請**填寫**版本
#         - 如果是使用雲端計算資源 (e.g. Colab) **不需填寫**版本
#         - 請**勿**使用**付費**資源
#     - **python 版本**
#         - 例如：3.6.9
#         - 填寫**至少**能執行的版本即可
#     - **安裝環境**
#         - 例如使用 `pip`、`conda` 等
#         - 助教會以虛擬環境測試
#     - **安裝套件**與**版本**
#         - 請使用 `requirements.txt` (如壓縮檔內的範例)
#         - 助教會以虛擬環境測試
#         - 請**不要**附上**多餘**的套件
#     - **計算資源**
#         - 主記憶體需求
#         - 有無使用 GPU
#         - GPU 版本
#         - GPU 記憶體需求
#     - **執行**所需花費**時間**
#         - 請**不要更改**擁有註解 `請勿更動此區塊程式碼` 的程式碼區塊
# 4. 請**保留執行結果**讓助教可以直接觀看
#     - 請記得使用 **Save**
#     - **雲端**計算資源請**儲存**後**下載**檔案
#     - 所有程式區塊**必須依序執行**
#     - 請**不要**保留**多餘**的程式區塊
# 5. 請**控制隨機亂數**讓實驗結果可以**重現**
#     - 關鍵字：**random seed**
# 6. 請**不要**上傳**多餘**的檔案
#     - 不要上傳**資料**檔案，包含 `train.csv` 與 `test.csv` 等
#     - 不要上傳**隱藏**檔案，包含 `.git`、`.ipynb_checkpoints` 等
#     - 不要上傳**虛擬環境**
# 7. 請附上**參考連結**
#     - 可以參考公開的 kernel
#     - 沒附上連結者視同**瓢竊**
#     - 使用的**演算法**請附上來源，並大致描述概念
# 8. 請**壓縮**成 `zip` 並上傳至 [moodle](http://moodle.ncku.edu.tw/)
#     - 例如 `HW1_F12345678.zip`

# %% [markdown]
# ## 評分標準
#
# 如果有參考其他作法卻沒有附上來源，則直接視為瓢竊，得分為 $-\infty$。
#
# |規則|滿足規則得分|沒滿足規則失分|
# |-|-|-|
# |資料夾名稱符合繳交規則|0|-60|
# |檔案名稱符合繳交規則|0|-60|
# |填寫環境需求|0|-60|
# |填寫計算資源|0|-60|
# |提供 `requirements.txt`|0|-60|
# |將資料夾壓縮成 `zip`|0|-60|
# |不更改擁有註解 `請勿更動此區塊程式碼` 的程式碼區塊|0|-60|
# |計算並顯示執行時間|0|-60|
# |控制隨機亂數讓實驗結果可以重現|0|-60|
# |使用 `markdown` 區塊描述資料分析內容|+3|-10|
# |以資料視覺化輔助資料分析並以 `markdown` 區塊輔助描述圖中資訊|+7|-10|
# |選擇使用 `Sex` 與 `Age` 以外的特徵作為輸入並以 `markdown` 區塊描述方法與理由|+5|-10|
# |處理缺失值並以 `markdown` 區塊描述方法與理由|+5|-10|
# |轉換數值資料並以 `markdown` 區塊描述方法與理由|+5|-10|
# |轉換類別資料並以 `markdown` 區塊描述方法與理由|+5|-10|
# |使用其他方法進行資料前處理並以 `markdown` 區塊描述理由|+10|0|
# |使用決策樹以外的模型進行實驗|+10|-10|
# |使用 `markdown` 區塊簡單解釋模型演算法|+10|0|
# |解釋模型超參數的選擇理由|+5|-10|
# |使用 5-fold cross validation 輸出平均準確度|+5|-10|
# |使用所有資料訓練模型並輸出準確度|+5|-10|
# |使用多個不同模型進行實驗|+10|0|
# |使用 ensemble 進行實驗|+10|0|
# |試著讓其中一個實驗模型 overfitting（訓練與驗證準確度差距 > $10\%$）|+9|0|
# |試著讓其中一個實驗模型 underfitting（訓練準確度約 $50\% \pm 10\%$）|+1|0|
# |準確度超越課堂範例（$81\%$）|+10|-10|
# |將最佳實驗結果套用到 `test.csv` 並截圖 Kaggle 評分|+10|0|
# |將最佳實驗結果套用到 `test.csv` 並取得 Kaggle Public Leaderboard Top $10\%$|+20|0|
# |將最佳實驗結果套用到 `test.csv` 並取得 Kaggle Public Leaderboard Top $5\%$|+30|0|
# |將最佳實驗結果套用到 `test.csv` 並取得 Kaggle Public Leaderboard Top $1\%$|+50|0|

# %% [markdown]
# ## 環境
#
# 請填寫當前執行使用的環境。
#
# |環境|名稱|版本|
# |-|-|-|
# |作業系統|Colab|-|
# |程式執行環境|Colab|-|
# |python 版本|python3|3.6.9|
# |安裝環境|-|-|

# %% [markdown]
# ## 安裝
#
# 請填寫安裝套件需要的指令
#
# ```sh
# pip install -r requirements.txt
# ```

# %% [markdown]
# ## 計算資源
#
# 請填寫執行程式所需要的計算資源。
#
# |計算資源|答案|
# |-|-|
# |主記憶體需求|$\leq 4$GB|
# |有無使用 GPU|無|
# |GPU 版本|無|
# |GPU 記憶體需求|$\leq 1$GB|

# %% [markdown]
# ## 參考連結
#
# - 有無參考他人之實驗結果：有
# - 參考連結：
# - [[資料分析&機器學習] 第4.1講 : Kaggle競賽-鐵達尼號生存預測](https://medium.com/jameslearningnote/%E8%B3%87%E6%96%99%E5%88%86%E6%9E%90-%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92-%E7%AC%AC4-1%E8%AC%9B-kaggle%E7%AB%B6%E8%B3%BD-%E9%90%B5%E9%81%94%E5%B0%BC%E8%99%9F%E7%94%9F%E5%AD%98%E9%A0%90%E6%B8%AC-%E5%89%8D16-%E6%8E%92%E5%90%8D-a8842fea7077)
# - [[機器學習專案] Kaggle競賽-鐵達尼號生存預測](https://yulongtsai.medium.com/https-medium-com-yulongtsai-titanic-top3-8e64741cc11f)
# - [ Titanic - Machine Learning from Disaster](https://www.kaggle.com/code/startupsci/titanic-data-science-solutions)

# %%
# 請勿更動此區塊程式碼

import time
import numpy as np
import pandas as pd

EXECUTION_START_TIME = time.time() # 計算執行時間

df = pd.read_csv('train.csv')      # 讀取資料，請勿更改路徑

# %% [markdown]
# ## 資料分析與前處理
#
# 請在此區塊後使用**一個或多個區塊**進行資料分析與前處理，項目可以包含：
#
# - 資料視覺化
# - 相關係數
# - 決定輸入特徵
# - 處理缺失值
# - 轉換數值
# - 轉換類別
# - 其他
#
# 請以 `markdown` 簡單描述**流程**、**方法**與**原因**：
#
# 1. 觀察...，發現...
# 2. 填補...，策略...
# 3. 轉換...，原因...

# %%
# 查看資料資訊
df.describe()  # 查看統計資訊
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 資料分析與前處理

train_x = df[['Sex', 'Age']]                   # 取出訓練資料需要分析的資料欄位
train_y = df['Survived']                       # 取出訓練資料的答案

from sklearn.impute import SimpleImputer       # 匯入填補缺失值的工具
from sklearn.preprocessing import LabelEncoder # 匯入 Label Encoder

imputer = SimpleImputer(strategy='median')     # 創造 imputer 並設定填補策略
age = train_x['Age'].to_numpy().reshape(-1, 1)
imputer.fit(age)                               # 根據資料學習需要填補的值
# train_x['Age'] = imputer.transform(age)        # 填補缺失值
df['Age'] = imputer.transform(age)             # 填補缺失值

le = LabelEncoder()                            # 創造 Label Encoder
le.fit(train_x['Sex'])                         # 給予每個類別一個數值
train_x['Sex'] = le.transform(train_x['Sex'])  # 轉換所有類別成為數值
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## 資料視覺化分析

# %%
# 資料視覺化輔助資料分析
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.countplot(df['Sex'], hue=df['Survived'])
df[["Sex", "Survived"]].groupby(['Sex']).mean().sort_values(by='Survived', ascending=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [markdown]
# - 性別與存活率的關係
# 男性存活數機率$\approx$18% 明顯低於女性$\approx$74%

# %%
sns.barplot(df['Pclass'], df['Survived'])
df[["Pclass", "Survived"]].groupby(['Pclass']).mean().sort_values(by='Survived', ascending=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# - 艙等與存活率
#   鐵達尼號共分三個艙等
#   - 1st = Upper
#   - 2nd = Middle
#   - 3rd = Lower
#
#   能夠負擔高等價位的上流人物理論上會獲得優先逃生與護衛的可能性，頭等艙的乘客生存機率會比較高

# %%
g = sns.FacetGrid(df, col='Survived')
g.map(sns.distplot, 'Age', kde=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# - 年齡與存活率
# 從年齡來看，見小的存活比例的確高出許多

# %% [markdown]
# ## 資料缺失處理

# %%
# 查看缺失項目
import pandas as pd
pd.isnull(df).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 先查看train中資料缺失的情況，主要有三項分別是：
# Age, Cabin, Embarked.
# Age在train_x中已處理完成，Titanic共891筆資料中Cabin缺失687筆，補救其缺失並無特徵工程上的意義
# 接著處理Embarked的缺失資料

# %%
freq_port = df.Embarked.dropna().mode()[0]
freq_port
# Out:
# 'S'

# %% [markdown]
# 因為在Embarked中資料缺失數量較少
# 我採用眾數值進行補齊，在這裡是S, Southampton

# %%
df['Embarked'] = df['Embarked'].fillna(freq_port)  
df[['Embarked', 'Survived']].groupby(['Embarked'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#   Embarked  Survived
# 0        C  0.553571
# 1        Q  0.389610
# 2        S  0.339009

# %%
pd.isnull(df).sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# 到此步驟除了打算忽略不用的Carbin外
# 其餘資料缺失直皆已補齊

# %% [markdown]
# ## 剩餘資料前處理

# %%
# extract people's name by symbol '.'
df['Title'] = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(df['Title'], df['Sex'])
# Out:
# Sex       female  male
# Title
# Capt           0     1
# Col            0     2
# Countess       1     0
# Don            0     1
# Dr             1     6
# Jonkheer       0     1
# Lady           1     0
# Major          0     2
# Master         0    40
# Miss         182     0
# Mlle           2     0
# Mme            1     0
# Mr             0   517
# Mrs          125     0
# Ms             1     0
# Rev            0     6
# Sir            0     1

# %% [markdown]
# - Title與存活率關係
# 在資料集中有一欄位為姓名類別，經由觀察發現在名字前端皆綴有稱呼（Title）如：Braund, Mr. Owen Harris
# 藉由extract函式可以分類出其稱號如Mr.、Mrs.並進行分析訓練

# %%
# 將數量較少的title歸類為rare
df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')

df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')
    
df[['Title', 'Survived']].groupby(['Title'], as_index=False).mean()
# Out:
#     Title  Survived
# 0  Master  0.575000
# 1    Miss  0.702703
# 2      Mr  0.156673
# 3     Mrs  0.793651
# 4    Rare  0.347826

# %% [markdown]
# 在稱謂中較少見的類別如Cap,Don等一律歸類至rare類別避免噪點

# %%
# convert Sex, Embarked and Title into integer 
df['Embarked'] = df['Embarked'].map( {'C': 0, 'Q': 1, 'S': 2} ).astype(int)
df['Sex'] = df['Sex'].map( {'male': 0, 'female': 1} ).astype(int)
#df['Fare'].fillna(df['Fare'].dropna().median(), inplace=True)

title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
df['Title'] = df['Title'].map(title_mapping)
df['Title'] = df['Title'].fillna(0)

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked  Title
# 0         A/5 21171   7.2500   NaN         2      1
# 1          PC 17599  71.2833   C85         0      3
# 2  STON/O2. 3101282   7.9250   NaN         2      2
# 3            113803  53.1000  C123         2      3
# ...

# %% [markdown]
# 最後將Sex, Embarked, Title等文字項欄位進行數值轉換方便模型訓練

# %%
print("Before", df.shape)
df = df.drop(['Name','PassengerId', 'Ticket','Cabin'], axis=1)

print("After", df.shape)
# Out:
# Before (891, 13)
# After (891, 9)

# %% [markdown]
# 不使用Name, PassengerId, Ticket和Cabin的資料，先拋棄釋放資源

# %% [markdown]
# ## 模型訓練
#
# 請在此區塊後使用**一個或多個區塊**進行模型訓練，**需要**包含以下內容：
#
# - **選擇模型**
#     - 設定模型**超參數**
#     - **控制隨機亂數**
# - 計算**準確度（Accuracy）**
#     - 使用 **5-fold cross validation**，輸出**平均準確度**
#     - 最後再使用**所有**資料進行訓練並輸出**準確度**
#     - 準確度必須**超越**課堂使用的範例
#
# 如果有進行多於一個以上的實驗，**可以保留所有**的實驗結果，但是執行時間將會納入**全部**實驗。

# %% [markdown]
# - 模型選擇
#   以下選用
#   1.   DecisionTreeClassifier
#   2.   LogisticRegression
#   3.   Radom Forest Classifier (為ensemble的一種)
#   4.   KNeighborsClassifier
#
#   並傳入train_x(Sex, Age)進行訓練
#
# - 超參數選擇
# 參考[scikit官方api](https://scikit-learn.org/stable/)中針對各個模型argument的定義
# 並採取try and errer 的策略反覆測試出最適當的參數值
#
# - 模型演算法
#   1. DecisionTreeClassifier: 決策樹是以一個貪婪法則來決定每一層要問什麼問題，目標是分類過後每一群能夠很明顯的知道是屬於哪一種類別。
#   2. LogisticRegression: 是一種分類的模型。其目標是要找出一條直線能夠將所有數據清楚地分開並做分類，利用 sigmoid function 將輸出轉換成 0~1 的值，表示可能為這個類別的機率值。
#   3. Radom Forest Classifier: 隨機森林其實就是進階版的決策樹，由很多棵決策樹所組成。隨使用 Bagging 加上隨機特徵採樣的方法所產生出來的整體學習演算法。
#   4. KNeighborsClassifier: 屬於機器學習中的 Supervised learning 其中一種算法。分類的標準是由鄰居「多數表決」決定的。在 Sklearn 中 KNN 可以用作分類或迴歸的模型。
#   演算法説明參考：[全民瘋AI系列2.0](https://ithelp.ithome.com.tw/users/20107247/ironman/4723)

# %%
# 固定隨機變數讓實驗結果可以重現
np.random.seed(2022)

train_x = df[['Sex', 'Age']]                   # 取出訓練資料需要分析的資料欄位
train_y = df['Survived']                       # 取出訓練資料的答案

# 模型訓練
from sklearn.model_selection import KFold             # 匯入 K 次交叉驗證工具
from sklearn.tree import DecisionTreeClassifier       # 匯入決策樹模型
from sklearn.metrics import accuracy_score            # 匯入準確度計算工具

kf = KFold(n_splits=5,                                # 設定 K 值
           random_state=1012,
           shuffle=True)
kf.get_n_splits(train_x)                              # 給予資料範圍

train_acc_list = []                                   # 儲存每次訓練模型的準確度
valid_acc_list = []                                   # 儲存每次驗證模型的準確度

for train_index, valid_index in kf.split(train_x):    # 每個迴圈都會產生不同部份的資料
    train_x_split = train_x.iloc[train_index]         # 產生訓練資料
    train_y_split = train_y.iloc[train_index]         # 產生訓練資料標籤
    valid_x_split = train_x.iloc[valid_index]         # 產生驗證資料
    valid_y_split = train_y.iloc[valid_index]         # 產生驗證資料標籤
    
    model = DecisionTreeClassifier(random_state=1012) # 創造決策樹模型
    model.fit(train_x_split, train_y_split)           # 訓練決策樹模型
    
    train_pred_y = model.predict(train_x_split)       # 確認模型是否訓練成功
    train_acc = accuracy_score(train_y_split,         # 計算訓練資料準確度
                               train_pred_y)
    valid_pred_y = model.predict(valid_x_split)       # 驗證模型是否訓練成功
    valid_acc = accuracy_score(valid_y_split,         # 計算驗證資料準確度
                               valid_pred_y)
    
    train_acc_list.append(train_acc)
    valid_acc_list.append(valid_acc)

print((
    'average train accuracy: {}\n' +
    '    min train accuracy: {}\n' +
    '    max train accuracy: {}\n' +
    'average valid accuracy: {}\n' +
    '    min valid accuracy: {}\n' +
    '    max valid accuracy: {}').format(
    np.mean(train_acc_list),                          # 輸出平均訓練準確度
    np.min(train_acc_list),                           # 輸出最低訓練準確度
    np.max(train_acc_list),                           # 輸出最高訓練準確度
    np.mean(valid_acc_list),                          # 輸出平均驗證準確度
    np.min(valid_acc_list),                           # 輸出最低驗證準確度
    np.max(valid_acc_list)                            # 輸出最高驗證準確度
))
# Out:
# average train accuracy: 0.8240765400192256
#     min train accuracy: 0.8176718092566619
#     max train accuracy: 0.8330995792426368
# average valid accuracy: 0.7598518611512147
#     min valid accuracy: 0.7318435754189944
#     max valid accuracy: 0.7865168539325843

# %%
# 邏輯回歸模型
from sklearn.linear_model import LogisticRegression
# 儲存模型的工具
import pickle      

kf = KFold(n_splits=5,                                # 設定 K 值
           random_state=1012,
           shuffle=True)
kf.get_n_splits(train_x)                              # 給予資料範圍

train_acc_list = []                                   # 儲存每次訓練模型的準確度
valid_acc_list = []                                   # 儲存每次驗證模型的準確度

for train_index, valid_index in kf.split(train_x):      # 每個迴圈都會產生不同部份的資料
    train_x_split = train_x.iloc[train_index]         # 產生訓練資料
    train_y_split = train_y.iloc[train_index]         # 產生訓練資料標籤
    valid_x_split = train_x.iloc[valid_index]         # 產生驗證資料
    valid_y_split = train_y.iloc[valid_index]         # 產生驗證資料標籤
    
    LR_Model = LogisticRegression(random_state=1012)    # 創造邏輯回歸模型
    LR_Model.fit(train_x_split, train_y_split)           # 訓練邏輯回歸模型
    
    train_pred_y = LR_Model.predict(train_x_split)       # 確認模型是否訓練成功
    train_acc = accuracy_score(train_y_split,         # 計算訓練資料準確度
                               train_pred_y)
    valid_pred_y = LR_Model.predict(valid_x_split)       # 驗證模型是否訓練成功
    valid_acc = accuracy_score(valid_y_split,         # 計算驗證資料準確度
                               valid_pred_y)
    
    train_acc_list.append(train_acc)
    valid_acc_list.append(valid_acc)
    pickle.dump(LR_Model,open('./LR_Model.pickle','wb')) #儲存模型

print((
    'average train accuracy: {}\n' +
    '    min train accuracy: {}\n' +
    '    max train accuracy: {}\n' +
    'average valid accuracy: {}\n' +
    '    min valid accuracy: {}\n' +
    '    max valid accuracy: {}').format(
    np.mean(train_acc_list),                          # 輸出平均訓練準確度
    np.min(train_acc_list),                           # 輸出最低訓練準確度
    np.max(train_acc_list),                           # 輸出最高訓練準確度
    np.mean(valid_acc_list),                          # 輸出平均驗證準確度
    np.min(valid_acc_list),                           # 輸出最低驗證準確度
    np.max(valid_acc_list)                            # 輸出最高驗證準確度
))
# Out:
# average train accuracy: 0.7867555982791498
#     min train accuracy: 0.7769985974754559
#     max train accuracy: 0.7994389901823282
# average valid accuracy: 0.7867428284476807
#     min valid accuracy: 0.7359550561797753
#     max valid accuracy: 0.8258426966292135

# %%
# Radom Forest Classifier (為ensemble的一種)
from sklearn.ensemble import RandomForestClassifier
kf = KFold(n_splits=5,                                # 設定 K 值
           random_state=1012,
           shuffle=True)
kf.get_n_splits(train_x)                              # 給予資料範圍

train_acc_list = []                                   # 儲存每次訓練模型的準確度
valid_acc_list = []                                   # 儲存每次驗證模型的準確度

for train_index, valid_index in kf.split(train_x):      # 每個迴圈都會產生不同部份的資料
    train_x_split = train_x.iloc[train_index]         # 產生訓練資料
    train_y_split = train_y.iloc[train_index]         # 產生訓練資料標籤
    valid_x_split = train_x.iloc[valid_index]         # 產生驗證資料
    valid_y_split = train_y.iloc[valid_index]         # 產生驗證資料標籤
    
    RFC_Model = RandomForestClassifier(random_state=1012) # 創造隨機森林模型
    RFC_Model.fit(train_x_split, train_y_split)           # 訓練隨機森林模型
    
    train_pred_y = RFC_Model.predict(train_x_split)       # 確認模型是否訓練成功
    train_acc = accuracy_score(train_y_split,         # 計算訓練資料準確度
                               train_pred_y)
    valid_pred_y = RFC_Model.predict(valid_x_split)       # 驗證模型是否訓練成功
    valid_acc = accuracy_score(valid_y_split,         # 計算驗證資料準確度
                               valid_pred_y)
    
    train_acc_list.append(train_acc)
    valid_acc_list.append(valid_acc)
    pickle.dump(RFC_Model,open('./RFC_Model.pickle','wb')) #儲存模型

print((
    'average train accuracy: {}\n' +
    '    min train accuracy: {}\n' +
    '    max train accuracy: {}\n' +
    'average valid accuracy: {}\n' +
    '    min valid accuracy: {}\n' +
    '    max valid accuracy: {}').format(
    np.mean(train_acc_list),                          # 輸出平均訓練準確度
    np.min(train_acc_list),                           # 輸出最低訓練準確度
    np.max(train_acc_list),                           # 輸出最高訓練準確度
    np.mean(valid_acc_list),                          # 輸出平均驗證準確度
    np.min(valid_acc_list),                           # 輸出最低驗證準確度
    np.max(valid_acc_list)                            # 輸出最高驗證準確度
))
# Out:
# average train accuracy: 0.8240765400192256
#     min train accuracy: 0.8176718092566619
#     max train accuracy: 0.8330995792426368
# average valid accuracy: 0.7665746029753311
#     min valid accuracy: 0.7134831460674157
#     max valid accuracy: 0.7921348314606742

# %%
# KNN模型
from sklearn.neighbors import KNeighborsClassifier

kf = KFold(n_splits=5,                                # 設定 K 值
           random_state=1012,
           shuffle=True)
kf.get_n_splits(train_x)                              # 給予資料範圍

train_acc_list = []                                   # 儲存每次訓練模型的準確度
valid_acc_list = []                                   # 儲存每次驗證模型的準確度

for train_index, valid_index in kf.split(train_x):      # 每個迴圈都會產生不同部份的資料
    train_x_split = train_x.iloc[train_index]         # 產生訓練資料
    train_y_split = train_y.iloc[train_index]         # 產生訓練資料標籤
    valid_x_split = train_x.iloc[valid_index]         # 產生驗證資料
    valid_y_split = train_y.iloc[valid_index]         # 產生驗證資料標籤
    
    KNN_Model = KNeighborsClassifier()                # 創造KNN模型
    KNN_Model.fit(train_x_split, train_y_split)       # 訓練KNN模型
    
    train_pred_y = KNN_Model.predict(train_x_split)       # 確認模型是否訓練成功
    train_acc = accuracy_score(train_y_split,         # 計算訓練資料準確度
                               train_pred_y)
    valid_pred_y = KNN_Model.predict(valid_x_split)       # 驗證模型是否訓練成功
    valid_acc = accuracy_score(valid_y_split,         # 計算驗證資料準確度
                               valid_pred_y)
    
    train_acc_list.append(train_acc)
    valid_acc_list.append(valid_acc)
    pickle.dump(KNN_Model,open('./KNN_Model.pickle','wb')) #儲存模型

print((
    'average train accuracy: {}\n' +
    '    min train accuracy: {}\n' +
    '    max train accuracy: {}\n' +
    'average valid accuracy: {}\n' +
    '    min valid accuracy: {}\n' +
    '    max valid accuracy: {}').format(
    np.mean(train_acc_list),                          # 輸出平均訓練準確度
    np.min(train_acc_list),                           # 輸出最低訓練準確度
    np.max(train_acc_list),                           # 輸出最高訓練準確度
    np.mean(valid_acc_list),                          # 輸出平均驗證準確度
    np.min(valid_acc_list),                           # 輸出最低驗證準確度
    np.max(valid_acc_list)                            # 輸出最高驗證準確度
))
# Out:
# average train accuracy: 0.7685294766534818
#     min train accuracy: 0.6437587657784011
#     max train accuracy: 0.8078541374474053
# average valid accuracy: 0.7137907224907413
#     min valid accuracy: 0.6067415730337079
#     max valid accuracy: 0.7584269662921348

# %% [markdown]
# ## 所有資料訓練模型
# 將Titanic資料庫中所有相關聯的八個變數:
# Sex, Age, Pclass, Parch, Fare, Embarked, SibSp, Title作為train_x
# 與 Survived作為 train_y，以決策樹模型進行訓練
# 並使用使用 5-fold cross validation 驗證平均準確度

# %%
train_x = df[['Sex', 'Age','Pclass','Parch','Fare', 'Embarked','SibSp','Title']]  
train_y = df[['Survived']]

# 模型訓練
from sklearn.model_selection import KFold             # 匯入 K 次交叉驗證工具
from sklearn.tree import DecisionTreeClassifier       # 匯入決策樹模型
from sklearn.metrics import accuracy_score            # 匯入準確度計算工具

kf = KFold(n_splits=5,                                # 設定 K 值
           random_state=1012,
           shuffle=True)
kf.get_n_splits(train_x)                              # 給予資料範圍

train_acc_list = []                                   # 儲存每次訓練模型的準確度
valid_acc_list = []                                   # 儲存每次驗證模型的準確度

for train_index, valid_index in kf.split(train_x):    # 每個迴圈都會產生不同部份的資料
    train_x_split = train_x.iloc[train_index]         # 產生訓練資料
    train_y_split = train_y.iloc[train_index]         # 產生訓練資料標籤
    valid_x_split = train_x.iloc[valid_index]         # 產生驗證資料
    valid_y_split = train_y.iloc[valid_index]         # 產生驗證資料標籤
    
    model = DecisionTreeClassifier(random_state=10) # 創造決策樹模型
    model.fit(train_x_split, train_y_split)           # 訓練決策樹模型
    
    train_pred_y = model.predict(train_x_split)       # 確認模型是否訓練成功
    train_acc = accuracy_score(train_y_split,         # 計算訓練資料準確度
                               train_pred_y)
    valid_pred_y = model.predict(valid_x_split)       # 驗證模型是否訓練成功
    valid_acc = accuracy_score(valid_y_split,         # 計算驗證資料準確度
                               valid_pred_y)
    
    train_acc_list.append(train_acc)
    valid_acc_list.append(valid_acc)
    pickle.dump(DecisionTreeClassifier,open('./DecisionTreeClassifier.pickle','wb')) #儲存模型

print((
    'average train accuracy: {}\n' +
    '    min train accuracy: {}\n' +
    '    max train accuracy: {}\n' +
    'average valid accuracy: {}\n' +
    '    min valid accuracy: {}\n' +
    '    max valid accuracy: {}').format(
    np.mean(train_acc_list),                          # 輸出平均訓練準確度
    np.min(train_acc_list),                           # 輸出最低訓練準確度
    np.max(train_acc_list),                           # 輸出最高訓練準確度
    np.mean(valid_acc_list),                          # 輸出平均驗證準確度
    np.min(valid_acc_list),                           # 輸出最低驗證準確度
    np.max(valid_acc_list)                            # 輸出最高驗證準確度
))
# Out:
# average train accuracy: 0.9848491892147437
#     min train accuracy: 0.9789621318373072
#     max train accuracy: 0.9901823281907434
# average valid accuracy: 0.7755696440901387
#     min valid accuracy: 0.7430167597765364
#     max valid accuracy: 0.8314606741573034

# %% [markdown]
# 實驗模型 overfitting（訓練與驗證準確度差距 =  15.574% ）

# %% [markdown]
# ## 加分題
#
# 請將訓練後的模型套用至 [Kaggle Titanic](https://www.kaggle.com/c/titanic/overview) `test.csv` 上，並上傳至 Kaggle 進行評分，**截圖**後**嵌入**至 `markdown` 區塊中。

# %%
test = pd.read_csv("./test.csv")
test_ID = pd.read_csv("./test.csv")
test.sample(5)
# Out:
#      PassengerId  Pclass                                               Name  \
# 359         1251       3  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...
# 374         1266       1              Dodge, Mrs. Washington (Ruth Vidaver)
# 341         1233       3                         Lundstrom, Mr. Thure Edvin
# 231         1123       1                           Willard, Miss. Constance
# 200         1092       3                                 Murphy, Miss. Nora
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 359  female  30.0      1      0  349910  15.5500   NaN        S
# 374  female  54.0      1      1   33638  81.8583   A34        S
# 341    male  32.0      0      0  350403   7.5792   NaN        S
# 231  female  21.0      0      0  113795  26.5500   NaN        S
# 200  female   NaN      0      0   36568  15.5000   NaN        Q

# %%
train_x = test[['Sex', 'Age','Pclass','Parch','Fare', 'Embarked','SibSp']]                   # 取出訓練資料需要分析的資料欄位

# 資料分析與前處理

from sklearn.impute import SimpleImputer       # 匯入填補缺失值的工具
from sklearn.preprocessing import LabelEncoder # 匯入 Label Encoder

imputer = SimpleImputer(strategy='median')     # 創造 imputer 並設定填補策略
age = train_x['Age'].to_numpy().reshape(-1, 1)
imputer.fit(age)                                 # 根據資料學習需要填補的值
test['Age'] = imputer.transform(age)             # 填補缺失值

fare = train_x['Fare'].to_numpy().reshape(-1, 1)
imputer.fit(age)                                 # 根據資料學習需要填補的值
test['Fare'] = imputer.transform(fare)             # 填補缺失值

le = LabelEncoder()                            # 創造 Label Encoder
le.fit(train_x['Sex'])                         # 給予每個類別一個數值
train_x['Sex'] = le.transform(train_x['Sex'])  # 轉換所有類別成為數值
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
test['Embarked'] = test['Embarked'].fillna('S')
test['Title'] = test.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

# 將數量較少的姓氏title歸類為rare
df['Title'] = df['Title'].replace(['Lady', 'Countess','Capt', 'Col','Don', 'Dr', 'Major', 'Rev', 'Sir', 'Jonkheer', 'Dona'], 'Rare')
df['Title'] = df['Title'].replace('Mlle', 'Miss')
df['Title'] = df['Title'].replace('Ms', 'Miss')
df['Title'] = df['Title'].replace('Mme', 'Mrs')
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked Title
# 0  34.5      0      0   330911   7.8292   NaN        Q    Mr
# 1  47.0      1      0   363272   7.0000   NaN        S   Mrs
# 2  62.0      0      0   240276   9.6875   NaN        Q    Mr
# 3  27.0      0      0   315154   8.6625   NaN        S    Mr
# 4  22.0      1      1  3101298  12.2875   NaN        S   Mrs

# %%
# convert Sex, Embarked and Title into integer 
test['Embarked'] = test['Embarked'].map( {'C': 0, 'Q': 1, 'S': 2} ).astype(int)
test['Sex'] = test['Sex'].map( {'male': 0, 'female': 1} ).astype(int)

title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Rare": 5}
test['Title'] = test['Title'].map(title_mapping)
test['Title'] = test['Title'].fillna(0)

print("Before", df.shape)
test = test.drop(['Name', 'Ticket','Cabin','Pclass','SibSp','Parch','Fare','Embarked','Title'], axis=1)

test.head()
# Out:
# Before (891, 9)
#    PassengerId  Sex   Age
# 0          892    0  34.5
# 1          893    1  47.0
# 2          894    0  62.0
# 3          895    0  27.0
# 4          896    1  22.0

# %%
pd.isnull(test).sum()
temp = test.copy(['PassengerId'])
print(temp.shape)
Id = temp.drop(['Sex','Age'], axis=1)
print(Id.shape)
test = test.drop(['PassengerId'], axis=1)
# Out:
# (418, 3)
# (418, 1)

# %%
RFC_Model_Testing = pickle.load(open('./RFC_Model.pickle', 'rb')) # 讀入模型
y_pred_RFC = RFC_Model_Testing.predict(test)
print(y_pred_RFC.shape)
# Out:
# (418,)

# %%
output = pd.DataFrame.from_records([{'PassengerId': temp['PassengerId'][i], 'Survived':  y_pred_RFC[i]} for i in range(len(y_pred_RFC))])
#output = pd.DataFrame({'PassengerId': Id, 'Survived': y_pred_RFC})
print(output)
print(output.shape)
output.to_csv('submission.csv', index=False)
print("submission was successfully saved")
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         1
# 4            896         1
# ..           ...       ...
# 413         1305         1
# 414         1306         1
# 415         1307         0
# 416         1308         1
# 417         1309         1
#
# [418 rows x 2 columns]
# (418, 2)
# submission was successfully saved

# %% [markdown]
# ![Kaggle Submission.png](data:image/png;base64,...)

# %%
# 請勿更動此區塊程式碼

EXECUTION_END_TIME = time.time() # 計算執行時間
print('total execution time: {}'.format(EXECUTION_END_TIME - EXECUTION_START_TIME))
# Out:
# total execution time: 4.7452638149261475
